# %% [markdown]
# Quesion 1: \
# Consider feature vectors, x1 = [2 3 4 8 9]<sup>T</sup> and x2 = [2 −3 −4 89]<sup>T</sup> . \
# i) How many features are there in x1 and x2? \
# ii) What are the L1, L2, and L<sub>∞</sub> norms for each feature vector?

# %% [markdown]
# i) There are 5 features in x1 and 4 features in x2

# %%
from random import randint

import numpy as np
from markdown_it.rules_inline import newline

#Question 3
x1 = np.array([2, 3, 4, 8, 9])
x2 = np.array([2, -3, -4, 89])
Norm1x1 = np.linalg.norm(x1,ord=1)
Norm2x1 = np.linalg.norm(x1,ord=2)
NormInfx1 = np.linalg.norm(x1,ord=np.inf)

Norm1x2 = np.linalg.norm(x2,ord=1)
Norm2x2 = np.linalg.norm(x2,ord=2)
NormInfx2 = np.linalg.norm(x2,ord=np.inf)

print('For x1: L1 =', Norm1x1,'L2 =', Norm2x1, 'and L∞ = ', NormInfx1)
print('For x2: L1 =', Norm1x2,'L2 =', Norm2x2, 'and L∞ = ', NormInfx2)
# Out:
# For x1: L1 = 26.0 L2 = 13.19090595827292 and L∞ =  9.0
# For x2: L1 = 98.0 L2 = 89.16277250063504 and L∞ =  89.0

# %% [markdown]
# Question 2: \
# A color image of size 1024x1024 is input to an algorithm which outputs a 64x64
# color image representing some important portions of the original image. [Hint: a color
# image comprises of multiple channels] \
# i) If the input is converted to a vector, x , calculate the length of the feature vector. \
# ii) If the output is converted to a vector, y, calculate the length of the output vector. \
# iii) The algorithm relates the input and output vectors, x and y respectively, as y =
# Wx + b, where W is a matrix and b is a vector. How many elements are there in
# matrix W? How many elements are in vector b?

# %% [markdown]
# i) Given that the image is 1024x1024 pixels, and that color images are made of 3 color channels, the total number of features is 3,145,728

# %% [markdown]
# ii) Similarly, since the output is a 64x64 image with 3 channels (R, G, and B), then the length of the output vector y will be 12,288

# %% [markdown]
# iii) The vector b must have the same number of elements as vector y, thus b also has 12,288 elements. Meanwhile, matrix W is multiplied by vector x, so one of its dimensions must have the same number of elements as vector x, while the other dimension must have the same number as y. 3,145,728 x 12,288 = 38,654,705,664 total elements in matrix W.

# %%
import numpy as np
from numpy.ma.core import size

x = np.zeros([1048576,1])
    w = np.ones([4096,1048576])
y = np.zeros([4096,1])
b = np.ones([4096,1])
print(size(x), size(y), size(y+b), size(w.dot(x)))

# %% [markdown]
# Question 3 \
# Calculate 1-norm, 2-norm, ∞-norm, and Frobenius norm of
# W = $$ \begin{bmatrix} 1 & -1 \\ 2 & 0 \end{bmatrix} $$

# %%
import numpy as np

#Question 3
W = np.array([[1,-1],[2,0]])
Norm1 = np.linalg.norm(W,ord=1)
Norm2 = np.linalg.norm(W,ord=2)
NormInf = np.linalg.norm(W,ord=np.inf)
FrobNorm = np.linalg.norm(W,ord='fro')

print('For the given matrix: \n1-norm =', Norm1,'\n2-norm =', Norm2,'\n∞-norm = ', NormInf,'\nand the Frobenius norm =', FrobNorm)
# Out:
# For the given matrix:
# 1-norm = 3.0
# 2-norm = 2.2882456112707374
# ∞-norm =  2.0
# and the Frobenius norm = 2.449489742783178

# %% [markdown]
# Question 4 \
# Use the Iris dataset and the code shown in class, but choose 3 out of the 4 original
# features instead of two and calculate the accuracy score of classification

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

iris = datasets.load_iris()
X = iris.data[:, :3] # Selecting first three features
y = iris.target

X_train, X_test, y_train, y_test=train_test_split(
    X,y,
    test_size=0.40,
    train_size=0.60,
    random_state=123,
    shuffle=True,
    stratify=y)

clf = svm.SVC()
clf.fit(X_train, y_train)
preds = clf.predict(X_test)

acc = accuracy_score(y_test,clf.predict(X_test) )
print(preds)
print(y_test)
print('accuracy score :', acc)
# Out:
# [1 1 1 1 0 2 2 0 0 2 0 2 2 1 2 0 1 2 0 2 2 0 2 0 0 2 1 0 0 0 0 0 1 2 0 1 1
#  2 0 1 0 2 2 2 0 2 2 2 0 0 1 1 2 1 2 1 1 2 1 1]
# [1 1 1 1 0 1 2 0 0 2 0 2 2 1 2 0 1 2 0 2 2 0 1 0 0 2 1 0 0 0 0 0 1 2 0 1 1
#  2 0 1 0 2 2 2 0 2 2 1 0 0 1 1 2 1 2 1 1 2 1 2]
# accuracy score : 0.9333333333333333

# %% [markdown]
# Question 5\
# In class, we used a neural network to learn how to calculate square root. Use
# that code and ideas to teach a neural network how to calculate the 7-th root of any integer
# between 1 and 100.

# %%
import tensorflow as tf
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from tensorflow.python.keras.optimizers import *
import numpy as np
import matplotlib.pyplot as plt
import random

#Load dataset
#split into input (X) and output (y)
X = np.arange(1,101)
X = X*1.0
y = X**(1/7)

X_train, X_test, y_train, y_test=train_test_split(
    X,y,
    test_size=0.40,
    train_size=0.60,
    random_state=123,
    shuffle=True)

#define keras model
model = Sequential()

model.add(Dense(6,input_dim=1,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(1))

#compile the keras model
opt = optimizers.Adam(learning_rate=0.001)
model.compile(loss='mse', optimizer=opt)

#fit the keras model on the dataset (CPU)
model.fit(X_train,y_train,epochs=2000,batch_size=10, verbose=0)
model.summary()

#make class predictions with the model
predictions = model.predict(X_test)

#summarize the first 10 cases
for i in range(10):
    print('%s => %.2f (expected %.2f)' %(X_test[i].item(), predictions[i].item(), y_test[i].item()) )

number_grid = np.linspace(1, 100, 100)
plt.scatter(X,y, label='data')
plotpred = model.predict(number_grid)
plt.plot(number_grid, plotpred , color='red', label='model')
plt.xlabel('number')
plt.ylabel('7th root')
plt.legend()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_24 (Dense)                │ (None, 6)              │            12 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 6)              │            42 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 6)              │            42 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 1)              │             7 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 311 (1.22 KB)
#  Trainable params: 103 (412.00 B)
#  Non-trainable params: 0 (0.00 B)
# ...

# %% [markdown]
# Question 6 \
# Use the Iris dataset and the neural network code shown in class to create a neural
# network model that takes sepal length as input and predicts petal length as output. [Hint:
# Use Numpy or Pandas to wrangle Iris dataset to help define your input and output. You
# are free to define the number of neurons in each layer.]

# %%
import tensorflow as tf
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np
import matplotlib.pyplot as plt

#Load dataset
#split into input (X) and output (y)
iris = datasets.load_iris()
X = iris.data[:,0] # Selecting sepal length as feature
y = iris.data[:,2] # Selecting petal length for target

X_train, X_test, y_train, y_test=train_test_split(
    X,y,
    test_size=0.40,
    train_size=0.60,
    random_state=123,
    shuffle=True)

#define keras model
model = Sequential()

model.add(Dense(6,input_dim=1,activation='relu'))
model.add(Dense(12,activation='relu'))
model.add(Dense(12,activation='relu'))
model.add(Dense(1))

#compile the keras model
opt = optimizers.Adam(learning_rate=0.001)
model.compile(loss='mse', optimizer=opt)


#fit the keras model on the dataset (CPU)
model.fit(X_train,y_train,epochs=2000,batch_size=10, verbose=0)
model.summary()

#make class predictions with the model
predictions = model.predict(X_test)

#summarize the first 10 cases
for i in range(10):
    print('%s => %.2f (expected %.2f)' %(X[i], predictions[i].item(), y_test[i]) )

number_grid = np.linspace(1, 10, 100)
plt.scatter(X,y, label='data')
plotpred = model.predict(number_grid)
plt.plot(number_grid, plotpred , color='red', label='model')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.legend()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_36 (Dense)                │ (None, 6)              │            12 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_37 (Dense)                │ (None, 12)             │            84 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_38 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_39 (Dense)                │ (None, 1)              │            13 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 797 (3.12 KB)
#  Trainable params: 265 (1.04 KB)
#  Non-trainable params: 0 (0.00 B)
# ...
